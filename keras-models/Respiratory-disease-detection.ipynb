# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1893773-7330-4541-9caa-9a3d3acbba60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1893773-7330-4541-9caa-9a3d3acbba60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !echo '{"username":"kushgabani","key":"2d5beec462b167cbb153b799f07b04f1"}' > /root/.kaggle/kaggle.json
# !kaggle datasets download -d vbookshelf/respiratory-sound-database
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading respiratory-sound-database.zip to /content
# 100% 3.67G/3.69G [01:47<00:00, 29.8MB/s]
# 100% 3.69G/3.69G [01:47<00:00, 36.7MB/s]

# %%
# !unzip /content/respiratory-sound-database.zip -d dataset
# Out:
# Archive:  /content/respiratory-sound-database.zip
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/101_1b1_Al_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/101_1b1_Al_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/101_1b1_Pr_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/101_1b1_Pr_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/102_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/102_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/103_2b2_Ar_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/103_2b2_Ar_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Al_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Al_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Ar_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Ar_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Ll_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Ll_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Lr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Lr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Pl_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Pl_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Pr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Pr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/105_1b1_Tc_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/105_1b1_Tc_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/106_2b1_Pl_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/106_2b1_Pl_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/106_2b1_Pr_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/106_2b1_Pr_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b3_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b4_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_2b5_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/107_3p2_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/108_1b1_Al_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/108_1b1_Al_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Al_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Al_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Ar_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Ar_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Ll_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Ll_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Lr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Lr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Pl_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Pl_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Pr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/109_1b1_Pr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1b1_Pr_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1b1_Pr_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Al_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Al_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Ll_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Ll_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Lr_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Lr_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Pr_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/110_1p1_Pr_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/111_1b2_Tc_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/111_1b2_Tc_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/111_1b3_Tc_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/111_1b3_Tc_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1b1_Lr_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1b1_Lr_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1p1_Ll_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1p1_Ll_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1p1_Pl_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1p1_Pl_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1p1_Pr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/112_1p1_Pr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Al_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Al_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Ar_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Ar_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Ll_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Ll_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Lr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Lr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Pl_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Pl_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Pr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/113_1b1_Pr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/114_1b4_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/115_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/115_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/116_1b2_Pl_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/116_1b2_Pl_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/116_1b2_Tc_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/116_1b2_Tc_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/117_1b2_Tc_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/117_1b2_Tc_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/117_1b3_Tc_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/117_1b3_Tc_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Al_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Al_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Ar_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Ar_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Ll_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Ll_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Lr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Lr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Pl_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Pl_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Pr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/118_1b1_Pr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/119_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/119_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Al_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Al_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Lr_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Lr_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Pl_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Pl_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Pr_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/120_1b1_Pr_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/121_1b1_Tc_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/121_1b1_Tc_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/121_1p1_Tc_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/121_1p1_Tc_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b1_Al_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b1_Al_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b1_Ar_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b1_Ar_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b1_Tc_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b1_Tc_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b2_Al_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b2_Al_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b2_Ar_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b2_Ar_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b2_Tc_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b2_Tc_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b3_Al_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b3_Al_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b3_Ar_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b3_Ar_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b3_Tc_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/122_2b3_Tc_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/123_1b1_Al_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/123_1b1_Al_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Al_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Al_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Ar_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Ar_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Ll_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Ll_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Lr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Lr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Pl_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Pl_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Pr_sc_Litt3200.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/124_1b1_Pr_sc_Litt3200.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/125_1b1_Tc_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/125_1b1_Tc_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/126_1b1_Al_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/126_1b1_Al_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/127_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/127_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/128_1b3_Tc_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/128_1b3_Tc_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/129_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/129_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p2_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p3_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_1p4_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b2_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b3_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2b4_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p3_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p3_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_2p5_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b3_Ll_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b3_Ll_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Lr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Lr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3b4_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p2_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p3_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/130_3p4_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/131_1b1_Al_sc_Meditron.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/131_1b1_Al_sc_Meditron.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/132_2b1_Lr_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/132_2b1_Lr_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/132_2b2_Lr_mc_LittC2SE.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/132_2b2_Lr_mc_LittC2SE.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p2_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Pr_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Tc_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p3_Tc_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Al_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Al_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Ar_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Ar_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Pl_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Pl_mc_AKGC417L.wav
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Pr_mc_AKGC417L.txt
#   inflating: dataset/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/133_2p4_Pr_mc_AKGC417L.wav
# ...
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p2_Tc_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p2_Tc_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Al_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Al_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Ar_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Ar_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Pl_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Pl_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Pr_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p3_Pr_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Al_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Al_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Ar_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Ar_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Pl_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Pl_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Pr_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Pr_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Tc_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_1p5_Tc_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Al_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Al_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Ar_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Ar_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Pl_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Pl_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Pr_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Pr_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Tc_mc_AKGC417L.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/213_2p2_Tc_mc_AKGC417L.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/214_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/214_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/215_1b2_Ar_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/215_1b2_Ar_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/215_1b3_Tc_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/215_1b3_Tc_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/216_1b1_Al_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/216_1b1_Al_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/216_1b1_Pl_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/216_1b1_Pl_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/217_1b1_Tc_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/217_1b1_Tc_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Al_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Al_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Lr_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Lr_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Pl_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Pl_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Pr_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1b1_Pr_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1p1_Ar_sc_Litt3200.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1p1_Ar_sc_Litt3200.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1p1_Pl_sc_Litt3200.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1p1_Pl_sc_Litt3200.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1p1_Pr_sc_Litt3200.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/218_1p1_Pr_sc_Litt3200.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b1_Ar_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b1_Ar_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b1_Tc_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b1_Tc_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b2_Ar_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b2_Ar_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b2_Tc_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b2_Tc_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b3_Tc_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/219_2b3_Tc_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/220_1b1_Tc_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/220_1b1_Tc_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/220_1b2_Al_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/220_1b2_Al_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Al_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Al_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Ar_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Ar_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Lr_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Lr_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Pl_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b1_Pl_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Al_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Al_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Ar_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Ar_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Lr_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Lr_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Pl_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b2_Pl_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Al_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Al_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Ar_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Ar_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Lr_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Lr_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Pr_mc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/221_2b3_Pr_mc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/222_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/222_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/222_1b1_Lr_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/222_1b1_Lr_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/222_1b1_Pr_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/222_1b1_Pr_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Al_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Al_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Ar_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Ar_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Ll_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Ll_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Lr_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Lr_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Pl_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Pl_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Pr_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/223_1b1_Pr_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/224_1b1_Tc_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/224_1b1_Tc_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/224_1b2_Al_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/224_1b2_Al_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/225_1b1_Pl_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/225_1b1_Pl_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Al_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Al_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Ll_sc_Meditron.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Ll_sc_Meditron.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Pl_sc_LittC2SE.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Pl_sc_LittC2SE.wav
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/filename_differences.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/filename_format.txt
#   inflating: dataset/respiratory_sound_database/Respiratory_Sound_Database/patient_diagnosis.csv

# %%
# %tensorflow_version 2.x

# Tools for working with directories
import shutil
import os

# Tools for data manipulation and EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Tools for working with Audios and its maniplation
import librosa
import librosa.display

# Libraries for creating and training the model
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from keras.callbacks import ReduceLROnPlateau
from keras.utils.vis_utils import plot_model

# Evaluation metrics (ROC-AUC curve)
from sklearn.metrics import roc_curve, auc

# Keras API for Neural Networks
shutil.rmtree("./dataset/respiratory_sound_database")
os.rename("./dataset/Respiratory_Sound_Database/Respiratory_Sound_Database", "./dataset/Respiratory_Sound_Database/data")
shutil.move("./dataset/Respiratory_Sound_Database/data", "./dataset/data")
shutil.rmtree("./dataset/Respiratory_Sound_Database")

# %%
# Storing the training_path
audio_path = "./dataset/data/audio_and_txt_files/"

# Getting filenames of all audios
def get_audio_paths():
  audios = []
  for r, _,files in os.walk(audio_path):
    for f in files:
      if f.split(".")[-1] == "wav":
        audios.append(audio_path + f); # Storing the audio files in a list

  return np.array(audios)

# %%
def get_csv_data(path):
  # Reading csv data using pandas
  return pd.read_csv(path, names = ["ID", "Disease"])

df = get_csv_data("./dataset/data/patient_diagnosis.csv")
df["Disease"].value_counts()
# Out:
# COPD              64
# Healthy           26
# URTI              14
# Bronchiectasis     7
# Bronchiolitis      6
# Pneumonia          6
# LRTI               2
# Asthma             1
# Name: Disease, dtype: int64

# %%
disease = {
          "Bronchiectasis" : 0,
          "Bronchiolitis" : 0,
          "COPD" : 0,
          "Healthy" : 0,
          "Pneumonia" : 0,
          "URTI" : 0,
          }

# Counting the number of samples for each class
for r, _, files in os.walk(audio_path):
  for audio in files:
    if (audio.split(".")[-1]) == "wav":
      patient_id = audio.split("_")[0]
      disease_name = list(df[ df["ID"] == int(patient_id)]["Disease"])[0]
      if disease_name not in ["LRTI", "Asthma"]:
        disease[disease_name] = disease[disease_name] + 1

# %%
disease
# Out:
# {'Bronchiectasis': 16,
#  'Bronchiolitis': 13,
#  'COPD': 793,
#  'Healthy': 35,
#  'Pneumonia': 37,
#  'URTI': 23}

# %%
def get_features_labels():
  feature = np.zeros((814, 40, 862))
  labels = []

  i = 0
  
  # Converting and audios into mfcc and storing it in feature and its corresponding labels in labels
  for audio in audios:
    filename = audio.split("/")[-1].split(".")[0]
    patient_id = filename.split("_")[0]
    diseases = list(df[ df["ID"] == int(patient_id)]["Disease"])[0]
    if diseases not in ["LRTI", "Asthma"]:
      clip, sr = librosa.load(audio)
      mfccs = librosa.feature.mfcc(y=clip, sr=sr, n_mfcc=40)
      if mfccs.shape[1] == 862:
        labels.append(diseases)
        feature[i] = mfccs
        i += 1
  return feature, np.array(labels)

# %%
# Plotting a audio recordings
clip, sr = librosa.load(audios[3])
mfccs = librosa.feature.mfcc(y=clip, sr=sr, n_mfcc=40)
fig, ax = plt.subplots(figsize = (14, 5))
librosa.display.specshow(librosa.power_to_db(mfccs))

# %%
def train_test_data():
  # Splitting the data into train and test
  X, y = get_features_labels()
  y = LabelBinarizer().fit_transform(y)
  return train_test_split(X.reshape(-1, 40, 862, 1), y, test_size = 0.2)

X_train, X_test, y_train, y_test = train_test_data()

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((651, 40, 862, 1), (651, 6), (163, 40, 862, 1), (163, 6))

# %%
def create_model():
  # Creating the model
  model = Sequential([
                      Conv2D(32, (3, 3), padding = "same", activation = "relu", input_shape = (40, 862, 1)), # First convolutional layer
                      MaxPool2D((2, 2)),
                      BatchNormalization(),
                      Conv2D(64, (3, 3), padding = "same", activation = "relu"), # Second convolutional layer
                      Conv2D(64, (3, 3), padding = "same", activation = "relu"), # Third convolutional layer
                      MaxPool2D((2, 2)),
                      BatchNormalization(),
                      Conv2D(128, (3, 3), padding = "same", activation = "relu"),# Fourth convolutional layer
                      MaxPool2D((2, 2)),
                      Flatten(),
                      Dense(64, activation = "relu"),# Hidden layer
                      Dropout(0.3),
                      Dense(6, activation = "softmax")# Output layer
  ])

  # Specifying Loss function, optimizer with learning rate and the evaluation metric
  model.compile(optimizer = Adam(lr = 3e-4),
                loss = "categorical_crossentropy",
                metrics = ["accuracy"])
  return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 40, 862, 32)       320
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 20, 431, 32)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 20, 431, 32)       128
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 20, 431, 64)       18496
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 431, 64)       36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 215, 64)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 10, 215, 64)       256
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 10, 215, 128)      73856
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 5, 107, 128)       0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 68480)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                4382784
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 390
# =================================================================
# Total params: 4,513,158
# Trainable params: 4,512,966
# Non-trainable params: 192
# _________________________________________________________________

# %%
# Plotting the CNN Architecture in a diagram
plot_model(model, show_shapes=True, show_layer_names = True)

# %%
def train_model(model, epochs, batch_size = 32):
  # Reducing learning rate when the model takes a flat road during training
  reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                factor=0.2,
                                patience=5,
                                min_lr=0.0001,
                                verbose = 1,
                                mode = "min")
  
  # Training the model on the training set
  history = model.fit(X_train, y_train,
                    epochs = epochs,
                    batch_size = batch_size
                    validation_data = (X_test, y_test),
                    callbacks = [reduce_lr]
                    )
  return history

history = train_model(model, 100, 32)

# %%
# Checking the loss and accuracy of the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test Loss : " + str(test_loss))
print("Test Accuracy : " + str(test_acc))
# Out:
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6565 - accuracy: 0.8712
# Test Loss : 0.6564850807189941
# Test Accuracy : 0.8711656332015991

# %%
# Plotting Loss and Accuracy graph for both training and testing data
def observe_loss_accuracy(history):
  plt.plot(history.history["accuracy"])
  plt.plot(history.history["val_accuracy"])
  plt.title("model accuracy")
  plt.xlabel('epoch')
  plt.ylabel("accuracy")
  plt.legend(['train', 'test'])
  plt.show()

# Plotting the train and test loss of the model
  plt.plot(history.history["loss"])
  plt.plot(history.history["val_loss"])
  plt.title("model loss")
  plt.xlabel('epoch')
  plt.ylabel("loss")
  plt.legend(['train', 'test'])
  plt.show();

observe_loss_accuracy(history)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a0f0b2a1a08f> in <module>()
#      16   plt.show();
#      17
# ---> 18 observe_loss_accuracy()
#
# TypeError: observe_loss_accuracy() missing 1 required positional argument: 'history'

# %%
# Making predictions for X_test
y_preds = model.predict(X_test)

# Plotting an ROC curve for each class

def plot_roc_curve(predictions, ground_truth):
  fig, ax = plt.subplots(figsize = (10, 10))
  for i, val in enumerate(list(disease)):
      fpr, tpr, thresholds = roc_curve(ground_truth[:,i].astype(int), predictions[:,i])
      ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (val, auc(fpr, tpr)))
  ax.legend()
  ax.set_xlabel('False Positive Rate')
  ax.set_ylabel('True Positive Rate')

plot_roc_curve(y_preds, y_test)

# %%
# Saving the model
model.save("respiratory-model", save_format = "h5")
